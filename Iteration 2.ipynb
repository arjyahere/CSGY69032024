target_cipher_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]

# The target ciphertext you want to decrypt
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

# Convert all hex ciphertexts to bytes
ciphertexts_bytes = [bytes.fromhex(ct) for ct in ciphertexts_hex]

# Initialize the key with None
key = [None] * len(ciphertexts_bytes[0])

# XOR ciphertexts and find likely space positions
for ct1, ct2 in combinations(ciphertexts_bytes, 2):
    xor_result = hex_xor(ct1.hex(), ct2.hex())
    likely_spaces = get_likely_spaces(xor_result)

    for pos in likely_spaces:
        if key[pos] is None:
            # If a space is likely, XOR with space character to find the key
            key[pos] = ct1[pos] ^ ord(' ')

# Convert the target ciphertext to bytes
target_ciphertext_bytes = bytes.fromhex(target_ciphertext_hex)

# Decrypt the target ciphertext with the current key
decrypted_target = decrypt_with_key(target_ciphertext_bytes, key)

print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# Decrypted Target Message (partial): ***********************************************************

# %%
from itertools import combinations

# Define a function to XOR two hex strings and return the result as a hex string
def hex_xor(hex1, hex2):
    xor = int(hex1, 16) ^ int(hex2, 16)
    return "{:x}".format(xor).zfill(len(hex1))

# Define a function to get the index of the most likely spaces in the XOR result
def get_likely_spaces(xor_result):
    return [i for i, x in enumerate(xor_result) if int(x, 16) in range(65, 91) or int(x, 16) in range(97, 123)]

# Define a function to decrypt a ciphertext with a key
def decrypt_with_key(ciphertext, key):
    return ''.join(chr(ciphertext[i] ^ key[i]) if key[i] is not None else '*' for i in range(len(ciphertext)))

# Define a function to determine if a piece of text is likely to be valid English
def is_english(text):
    # A simple heuristic: count the number of English letters and spaces
    return sum(c.isalpha() or c.isspace() for c in text) > len(text) // 2

# Add your ciphertexts here
# Hex-encoded ciphertexts
c1="71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840"
c2="71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3"
c3="72fe069c51c81a20775928c7879d4fd2a93c3acff3f69fe5fe2e9493a303d9ea98c4e5b60ae40a146058e7c787fbd09a1474e25dc865b5e6af865d4a40a61bfd384e06e0cfc1ccd356ff8853ac438905fa5fe3fd41cb3bbc8ac9"
c4="67e543885b9a5b2267177084cf8453ccb8633ad7fdb39de5b13f8a93a304d6bf8bc4f4ef5def110b6f56a3e186e2c68c1470ef5c9c2ffbd6a291571e40ba1afd3b4b1fe0c4cbccc15df5dc07b043da01fa6ae4fd158f37b3c0cd"
c5="71fe029a148c1236320d7192878a59cfbc3a6ec5e7f68befb13196d6ea1ec4ea81d9e3fe50ea0f196d02a2f7cfe2c29c5577e35d8630baf6ea80465b01aa1abc394f57a1f4ccccda59ff8846e44b8805bb5cabe608c231f2dec8364ae7d90ab4358c5c3a421b06"
c6="6ef914ce5989152b321a769ad79c42c7be6f6ad2fab19de1fc339d84f04ad3a589dfa0ff09ab0c196f13e7e780b4c097556ded57c871fbeea393464a01aa0ab1381848cfd2d6898918efc046b00b8940bb08e3f313cb23b3dfd8645cfcd80ff82489"
c7="71fe1ace4389087266117cd7c4865bd2b93b7fd2b5a58ce9f4308c9ff01e97ab82cbf2ef5dfc101d6a56b3fb8ab4d08b4167ef5c9c30b8f0ab97455b45e81efd364605e49ddb83df48eedc42b60c900fb14db4b229ca74b6c4d96442e1c34df8288f5c3a450a527ecc7c82865b8e"
c8="71fe029a148c1437615978d7c58854dbec2c75cde5a39be5e37e9b97ef0697a285dfa0f01cff101d764983f29bf5"
c9="71fe1ace50875b31730d6ad7cb8640c7ec3c73d4e1bf81e7b13796d6e518d8a4988ceff05dff101d2415a8fe9fe1d79a4623eb5e8430bfe3b3d442514faf40fd18420be0c8cb89924cf3cd5ee448950efd5cabe500c120f2d9d26440ebc34de029811977430b01748276d79012955cc6a65aebb9054becda5c9278"
c10="71fe029a1483123c76597691878459cca9363ac4faf68ceffc2e8d82e61897b98fc5e5f809e20b0c7756b2e08aab83bc5560e257"
target_cipher_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]
# The target ciphertext you want to decrypt
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"


# Convert all hex ciphertexts to bytes
ciphertexts_bytes = [bytes.fromhex(ct) for ct in ciphertexts_hex]

# Initialize an empty key with the same length as the ciphertexts
key = [None] * len(ciphertexts_bytes[0])

# Iterate over all combinations of the ciphertexts
for ct1, ct2 in combinations(range(len(ciphertexts_bytes)), 2):
    # XOR the two ciphertexts
    xor_result = hex_xor(ciphertexts_hex[ct1], ciphertexts_hex[ct2])
    # Get the likely positions of spaces in the XOR result
    likely_spaces = get_likely_spaces(xor_result)
    
    # For each likely space position, try to guess the key
    for pos in likely_spaces:
        if key[pos] is None:
            # Guess that this position in ct1 has a space
            guessed_key_char = ciphertexts_bytes[ct1][pos] ^ ord(' ')
            # Decrypt ct2 with the guessed key character
            decrypted_text = decrypt_with_key(ciphertexts_bytes[ct2], [guessed_key_char] * len(ciphertexts_bytes[ct2]))
            # Check if the decrypted text is likely to be English
            if is_english(decrypted_text):
                # If it is, update the key at this position
                key[pos] = guessed_key_char

# Decrypt the target ciphertext with the guessed key
target_ciphertext_bytes = bytes.fromhex(target_ciphertext_hex)
decrypted_target = decrypt_with_key(target_ciphertext_bytes, key)

# Print the partially decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# Decrypted Target Message (partial): ***********************************************************

# %%
from itertools import combinations
import string

def hex_xor(hex1, hex2):
    """XOR two hex strings."""
    # Make sure both hex strings are of the same length
    max_len = max(len(hex1), len(hex2))
    hex1, hex2 = hex1.zfill(max_len), hex2.zfill(max_len)
    xor = int(hex1, 16) ^ int(hex2, 16)
    return "{:x}".format(xor).zfill(max_len)

def is_likely_letter(x):
    """Check if the xor result could correspond to a letter (upper or lowercase) xor-ed with a space."""
    x = int(x, 16)
    return (x ^ 0x20) in range(65, 91) or x in range(65, 91)

def get_likely_spaces(xor_result):
    """Find likely spaces in the XOR result by looking for common English letters."""
    return [i for i in range(0, len(xor_result), 2) if is_likely_letter(xor_result[i:i+2])]

def decrypt_with_key(ciphertext, key):
    """Decrypt a ciphertext with a key."""
    return ''.join(chr(b ^ key[i]) if i < len(key) and key[i] is not None else '*' for i, b in enumerate(ciphertext))

# Hex-encoded ciphertexts
c1="71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840"
c2="71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3"
c3="72fe069c51c81a20775928c7879d4fd2a93c3acff3f69fe5fe2e9493a303d9ea98c4e5b60ae40a146058e7c787fbd09a1474e25dc865b5e6af865d4a40a61bfd384e06e0cfc1ccd356ff8853ac438905fa5fe3fd41cb3bbc8ac9"
c4="67e543885b9a5b2267177084cf8453ccb8633ad7fdb39de5b13f8a93a304d6bf8bc4f4ef5def110b6f56a3e186e2c68c1470ef5c9c2ffbd6a291571e40ba1afd3b4b1fe0c4cbccc15df5dc07b043da01fa6ae4fd158f37b3c0cd"
c5="71fe029a148c1236320d7192878a59cfbc3a6ec5e7f68befb13196d6ea1ec4ea81d9e3fe50ea0f196d02a2f7cfe2c29c5577e35d8630baf6ea80465b01aa1abc394f57a1f4ccccda59ff8846e44b8805bb5cabe608c231f2dec8364ae7d90ab4358c5c3a421b06"
c6="6ef914ce5989152b321a769ad79c42c7be6f6ad2fab19de1fc339d84f04ad3a589dfa0ff09ab0c196f13e7e780b4c097556ded57c871fbeea393464a01aa0ab1381848cfd2d6898918efc046b00b8940bb08e3f313cb23b3dfd8645cfcd80ff82489"
c7="71fe1ace4389087266117cd7c4865bd2b93b7fd2b5a58ce9f4308c9ff01e97ab82cbf2ef5dfc101d6a56b3fb8ab4d08b4167ef5c9c30b8f0ab97455b45e81efd364605e49ddb83df48eedc42b60c900fb14db4b229ca74b6c4d96442e1c34df8288f5c3a450a527ecc7c82865b8e"
c8="71fe029a148c1437615978d7c58854dbec2c75cde5a39be5e37e9b97ef0697a285dfa0f01cff101d764983f29bf5"
c9="71fe1ace50875b31730d6ad7cb8640c7ec3c73d4e1bf81e7b13796d6e518d8a4988ceff05dff101d2415a8fe9fe1d79a4623eb5e8430bfe3b3d442514faf40fd18420be0c8cb89924cf3cd5ee448950efd5cabe500c120f2d9d26440ebc34de029811977430b01748276d79012955cc6a65aebb9054becda5c9278"
c10="71fe029a1483123c76597691878459cca9363ac4faf68ceffc2e8d82e61897b98fc5e5f809e20b0c7756b2e08aab83bc5560e257"
target_cipher_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]

# Convert all hex ciphertexts to bytes
ciphertexts_bytes = [bytes.fromhex(ct) for ct in ciphertexts_hex]

# Initialize an empty key with the same length as the ciphertexts
key = [None] * len(ciphertexts_bytes[0])

# Iterate over all combinations of the ciphertexts
for (index_a, ct_a), (index_b, ct_b) in combinations(enumerate(ciphertexts_bytes), 2):
    # XOR the two ciphertexts
    xor_result = hex_xor(ct_a.hex(), ct_b.hex())
    # Get the likely positions of spaces in the XOR result
    likely_spaces = get_likely_spaces(xor_result)

    # Debug: print XOR result and likely spaces
    print(f"XOR of ciphertext {index_a} and {index_b}: {xor_result}")
    print(f"Likely letter positions: {likely_spaces}")

    # For each likely space position, try to guess the key
    for pos in likely_spaces:
        pos //= 2  # Convert from hex index to byte index
        if key[pos] is None:
            # Guess that this position in ct_a has a space or letter
            guessed_key_char = ct_a[pos] ^ ord(' ')
            # Test the guessed key char against all other ciphertexts
            valid_for_all = all(
                chr(ct_b[pos] ^ guessed_key_char) in string.printable
                for ct_b in ciphertexts_bytes if len(ct_b) > pos
            )
            # If the guessed key character results in printable characters for all ciphertexts, it is likely correct
            if valid_for_all:
                key[pos] = guessed_key_char

# Decrypt the target ciphertext with the guessed key
target_ciphertext_bytes = bytes.fromhex(target_ciphertext_hex)
decrypted_target = decrypt_with_key(target_ciphertext_bytes, key)

# Print the partially decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# XOR of ciphertext 0 and 1: 
# Likely letter positions: [4, 20, 22, 26, 30, 32, 46, 50, 58, 66, 72, 84, 86, 90, 104, 110, 124, 136, 154, 168, 188, 206, 212, 220, 226, 230, 246, 250, 254, 276]
# XOR of ciphertext 0 and 2: 
# Likely letter positions: [4, 20, 22, 26, 30, 32, 46, 50, 62, 64, 68, 72, 100, 102, 106, 124, 132, 136, 146, 156, 172, 184, 202, 208, 260]
# XOR of ciphertext 0 and 3: 
# Likely letter positions: [2, 42, 52, 66, 70, 78, 92, 100, 104, 108, 110, 112, 122, 124, 126, 134, 166, 176, 180, 204, 236, 246, 248, 258, 274, 282]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 60
#      58 for pos in likely_spaces:
#      59     pos //= 2  # Convert from hex index to byte index
# ---> 60     if key[pos] is None:
#      61         # Guess that this position in ct_a has a space or letter
#      62         guessed_key_char = ct_a[pos] ^ ord(' ')
#      63         # Test the guessed key char against all other ciphertexts
#
# IndexError: list index out of range

# %%
from itertools import combinations
import string

def hex_xor(hex1, hex2):
    """XOR two hex strings."""
    # Ensure the hex strings are of the same length
    max_len = max(len(hex1), len(hex2))
    hex1 = hex1.zfill(max_len)
    hex2 = hex2.zfill(max_len)
    xor = int(hex1, 16) ^ int(hex2, 16)
    # Return the XOR result as a hex string, padded with zeros to the maximum length
    return "{:x}".format(xor).zfill(max_len)

def is_likely_letter(byte):
    """Check if a byte could be an XOR of a letter and a space."""
    return chr(byte ^ 0x20).isalpha()

def decrypt_with_key(ciphertext, key):
    """Decrypt a ciphertext with a key."""
    return ''.join(chr(byte ^ key_byte) if key_byte is not None else '*' for byte, key_byte in zip(ciphertext, key))

# Add your ciphertexts here
c1 = ""
c2 = "234c02ecbbfbafa3ed18510abd11fa724fcda2018a1a8342cf064bbde548b12b07df44ba7191d9606ef4081ffde5ad46a5069d9f7f543bedb9c861bf29c7e205132eda9382b0bc2c5c4b45f919cf3a9f1cb74151f6d551f4480c82b2cb24cc5b028aa76eb7b4ab24171ab3cdadb8356f"
c3 = "32510ba9a7b2bba9b8005d43a304b5714cc0bb0c8a34884dd91304b8ad40b62b07df44ba6e9d8a2368e51d04e0e7b207b70b9b8261112bacb6c866a232dfe257527dc29398f5f3251a0d47e503c66e935de81230b59b7afb5f41afa8d661cb"
c4 = ""
c5 = "3f561ba9adb4b6ebec54424ba317b564418fac0dd35f8c08d31a1fe9e24fe56808c213f17c81d9607cee021dafe1e001b21ade877a5e68bea88d61b93ac5ee0d562e8e9582f5ef375f0a4ae20ed86e935de81230b59b73fb4302cd95d770c65b40aaa065f2a5e33a5a0bb5dcaba43722130f042f8ec85b7c2070"
c6 = ""
c7 = ""
c8 = "315c4eeaa8b5f8bffd11155ea506b56041c6a00c8a08854dd21a4bbde54ce56801d943ba708b8a3574f40c00fff9e00fa1439fd0654327a3bfc860b92f89ee04132ecb9298f5fd2d5e4b45e40ecc3b9d59e9417df7c95bba410e9aa2ca24c5474da2f276baa3ac325918b2daada43d6712150441c2e04f6565517f317da9d3"
c9 = ""
c10 = "466d06ece998b7a2fb1d464fed2ced7641ddaa3cc31c9941cf110abbf409ed39598005b3399ccfafb61d0315fca0a314be138a9f32503bedac8067f03adbf3575c3b8edc9ba7f537530541ab0f9f3cd04ff50d66f1d559ba520e89a2cb2a83"
ciphertexts_hex = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]

# The target ciphertext you want to decrypt
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"


# Convert all hex ciphertexts to bytes
ciphertexts_bytes = [bytes.fromhex(ct) for ct in ciphertexts_hex]

# Initialize an empty key with None values, with the same length as the ciphertexts
key = [None] * len(max(ciphertexts_bytes, key=len))

# Iterate over all combinations of the ciphertexts
for idx_a, idx_b in combinations(range(len(ciphertexts_bytes)), 2):
    ct_a = ciphertexts_bytes[idx_a]
    ct_b = ciphertexts_bytes[idx_b]
    xor_result = hex_xor(ct_a.hex(), ct_b.hex())
    # Analyze the XOR result for likely spaces by checking if the result could be a letter XORed with a space
    for i in range(0, len(xor_result), 2):
        byte_xor = int(xor_result[i:i+2], 16)
        if is_likely_letter(byte_xor):
            byte_pos = i // 2
            if key[byte_pos] is None:
                key_byte_a = ct_a[byte_pos]
                key_byte_b = ct_b[byte_pos]
                # If the XOR of two bytes is a letter, one of the original bytes might be a space
                if chr(key_byte_a ^ 0x20).isalpha():
                    key[byte_pos] = key_byte_a ^ 0x20
                elif chr(key_byte_b ^ 0x20).isalpha():
                    key[byte_pos] = key_byte_b ^ 0x20

# Decrypt the target ciphertext with the partial key
target_ciphertext_bytes = bytes.fromhex(target_ciphertext_hex)
decrypted_target = decrypt_with_key(target_ciphertext_bytes, key)

# Print the partially decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 57
#      55 if key[byte_pos] is None:
#      56     key_byte_a = ct_a[byte_pos]
# ---> 57     key_byte_b = ct_b[byte_pos]
#      58     # If the XOR of two bytes is a letter, one of the original bytes might be a space
#      59     if chr(key_byte_a ^ 0x20).isalpha():
#
# IndexError: index out of range

# %%
from itertools import combinations

def hex_xor(hex1, hex2):
    """XOR two hex strings."""
    # Make sure both hex strings are of the same length by padding the shorter one with leading zeros
    max_len = max(len(hex1), len(hex2))
    hex1, hex2 = hex1.zfill(max_len), hex2.zfill(max_len)
    xor = int(hex1, 16) ^ int(hex2, 16)
    return f"{xor:0{max_len}x}"

def is_likely_letter(byte_xor):
    """Check if the XOR result corresponds to a space (' ') XORed with a printable character."""
    return byte_xor >= 65 and byte_xor <= 122  # ASCII range for uppercase and lowercase English letters

def decrypt_with_key(ciphertext, key):
    """Decrypt a ciphertext with a key."""
    return "".join(chr(byte ^ key_byte) if key_byte is not None else "*" for byte, key_byte in zip(ciphertext, key))

# Hex-encoded ciphertexts
c1="71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840"
c2="71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3"
c3="72fe069c51c81a20775928c7879d4fd2a93c3acff3f69fe5fe2e9493a303d9ea98c4e5b60ae40a146058e7c787fbd09a1474e25dc865b5e6af865d4a40a61bfd384e06e0cfc1ccd356ff8853ac438905fa5fe3fd41cb3bbc8ac9"
c4="67e543885b9a5b2267177084cf8453ccb8633ad7fdb39de5b13f8a93a304d6bf8bc4f4ef5def110b6f56a3e186e2c68c1470ef5c9c2ffbd6a291571e40ba1afd3b4b1fe0c4cbccc15df5dc07b043da01fa6ae4fd158f37b3c0cd"
c5="71fe029a148c1236320d7192878a59cfbc3a6ec5e7f68befb13196d6ea1ec4ea81d9e3fe50ea0f196d02a2f7cfe2c29c5577e35d8630baf6ea80465b01aa1abc394f57a1f4ccccda59ff8846e44b8805bb5cabe608c231f2dec8364ae7d90ab4358c5c3a421b06"
c6="6ef914ce5989152b321a769ad79c42c7be6f6ad2fab19de1fc339d84f04ad3a589dfa0ff09ab0c196f13e7e780b4c097556ded57c871fbeea393464a01aa0ab1381848cfd2d6898918efc046b00b8940bb08e3f313cb23b3dfd8645cfcd80ff82489"
c7="71fe1ace4389087266117cd7c4865bd2b93b7fd2b5a58ce9f4308c9ff01e97ab82cbf2ef5dfc101d6a56b3fb8ab4d08b4167ef5c9c30b8f0ab97455b45e81efd364605e49ddb83df48eedc42b60c900fb14db4b229ca74b6c4d96442e1c34df8288f5c3a450a527ecc7c82865b8e"
c8="71fe029a148c1437615978d7c58854dbec2c75cde5a39be5e37e9b97ef0697a285dfa0f01cff101d764983f29bf5"
c9="71fe1ace50875b31730d6ad7cb8640c7ec3c73d4e1bf81e7b13796d6e518d8a4988ceff05dff101d2415a8fe9fe1d79a4623eb5e8430bfe3b3d442514faf40fd18420be0c8cb89924cf3cd5ee448950efd5cabe500c120f2d9d26440ebc34de029811977430b01748276d79012955cc6a65aebb9054becda5c9278"
c10="71fe029a1483123c76597691878459cca9363ac4faf68ceffc2e8d82e61897b98fc5e5f809e20b0c7756b2e08aab83bc5560e257"
target_cipher_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]

# The target ciphertext you want to decrypt
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"


# Convert all hex ciphertexts to byte arrays
ciphertexts = [bytes.fromhex(c) for c in ciphertexts_hex]

# Initialize an empty key with the same length as the longest ciphertext
key = [None] * max(len(c) for c in ciphertexts)

# Iterate over all combinations of the ciphertexts
for idx_a, idx_b in combinations(range(len(ciphertexts)), 2):
    ct_a = ciphertexts[idx_a]
    ct_b = ciphertexts[idx_b]
    xor_result = hex_xor(ct_a.hex(), ct_b.hex())
    # For each byte in the XOR result, check if it is a likely letter
    for i in range(len(xor_result) // 2):
        byte_xor = int(xor_result[i*2:i*2+2], 16)
        if is_likely_letter(byte_xor):
            # Check if we can infer a space in either ct_a or ct_b at this position
            if i < len(ct_a) and i < len(ct_b):
                if key[i] is None:
                    if ct_a[i] == byte_xor ^ 0x20 or ct_b[i] == byte_xor ^ 0x20:
                        # We assume that the original character was a space
                        key[i] = byte_xor ^ 0x20

# Convert the target ciphertext to bytes
target_ciphertext_bytes = bytes.fromhex(target_ciphertext_hex)

# Decrypt the target ciphertext with the key
decrypted_target = decrypt_with_key(target_ciphertext_bytes, key)

# Print the partially decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# Decrypted Target Message (partial): ***********************************************************

# %%
from itertools import combinations

def hex_xor(hex1, hex2):
    """XOR two hex strings."""
    # Find the shorter length
    length = min(len(hex1), len(hex2))
    # Truncate the longer string and XOR bit by bit
    xor = int(hex1[:length], 16) ^ int(hex2[:length], 16)
    # Return as hex with left zero padding
    return f"{xor:0{length}x}"

def get_key(ciphertexts):
    """Given a list of ciphertexts, attempt to derive the key."""
    key = [None] * min(map(len, ciphertexts))  # initialize the shortest length of the ciphertexts
    # Try to find the key by XORing all combinations of ciphertexts
    for idx_a, idx_b in combinations(range(len(ciphertexts)), 2):
        ct_a, ct_b = ciphertexts[idx_a], ciphertexts[idx_b]
        # Only consider the overlapping part of both ciphertexts
        xor_result = hex_xor(ct_a.hex(), ct_b.hex())
        for i in range(0, len(xor_result), 2):
            byte_xor = int(xor_result[i:i+2], 16)
            # Assuming that a space (0x20) was XORed with a letter
            if 65 <= byte_xor ^ 0x20 <= 90 or 97 <= byte_xor ^ 0x20 <= 122:
                if key[i//2] is None:
                    key[i//2] = byte_xor ^ 0x20
    return key

def decrypt_with_key(ciphertext, key):
    """Decrypt a ciphertext with a key."""
    return "".join(chr(byte ^ key_byte) if key_byte is not None else "*" for byte, key_byte in zip(ciphertext, key))

# Add your ciphertexts here
# Hex-encoded ciphertexts
c1="71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840"
c2="71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3"
c3="72fe069c51c81a20775928c7879d4fd2a93c3acff3f69fe5fe2e9493a303d9ea98c4e5b60ae40a146058e7c787fbd09a1474e25dc865b5e6af865d4a40a61bfd384e06e0cfc1ccd356ff8853ac438905fa5fe3fd41cb3bbc8ac9"
c4="67e543885b9a5b2267177084cf8453ccb8633ad7fdb39de5b13f8a93a304d6bf8bc4f4ef5def110b6f56a3e186e2c68c1470ef5c9c2ffbd6a291571e40ba1afd3b4b1fe0c4cbccc15df5dc07b043da01fa6ae4fd158f37b3c0cd"
c5="71fe029a148c1236320d7192878a59cfbc3a6ec5e7f68befb13196d6ea1ec4ea81d9e3fe50ea0f196d02a2f7cfe2c29c5577e35d8630baf6ea80465b01aa1abc394f57a1f4ccccda59ff8846e44b8805bb5cabe608c231f2dec8364ae7d90ab4358c5c3a421b06"
c6="6ef914ce5989152b321a769ad79c42c7be6f6ad2fab19de1fc339d84f04ad3a589dfa0ff09ab0c196f13e7e780b4c097556ded57c871fbeea393464a01aa0ab1381848cfd2d6898918efc046b00b8940bb08e3f313cb23b3dfd8645cfcd80ff82489"
c7="71fe1ace4389087266117cd7c4865bd2b93b7fd2b5a58ce9f4308c9ff01e97ab82cbf2ef5dfc101d6a56b3fb8ab4d08b4167ef5c9c30b8f0ab97455b45e81efd364605e49ddb83df48eedc42b60c900fb14db4b229ca74b6c4d96442e1c34df8288f5c3a450a527ecc7c82865b8e"
c8="71fe029a148c1437615978d7c58854dbec2c75cde5a39be5e37e9b97ef0697a285dfa0f01cff101d764983f29bf5"
c9="71fe1ace50875b31730d6ad7cb8640c7ec3c73d4e1bf81e7b13796d6e518d8a4988ceff05dff101d2415a8fe9fe1d79a4623eb5e8430bfe3b3d442514faf40fd18420be0c8cb89924cf3cd5ee448950efd5cabe500c120f2d9d26440ebc34de029811977430b01748276d79012955cc6a65aebb9054becda5c9278"
c10="71fe029a1483123c76597691878459cca9363ac4faf68ceffc2e8d82e61897b98fc5e5f809e20b0c7756b2e08aab83bc5560e257"
target_cipher_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]

# The target ciphertext you want to decrypt
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"


# Convert all hex ciphertexts to byte arrays
ciphertexts = [bytes.fromhex(ct) for ct in ciphertexts_hex]

# Derive the key using the ciphertexts
key = get_key(ciphertexts)

# Convert the target ciphertext to bytes and decrypt it with the key
target_ciphertext = bytes.fromhex(target_ciphertext_hex)
decrypted_target = decrypt_with_key(target_ciphertext, key)

# Print the decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 56
#      53 ciphertexts = [bytes.fromhex(ct) for ct in ciphertexts_hex]
#      55 # Derive the key using the ciphertexts
# ---> 56 key = get_key(ciphertexts)
#      58 # Convert the target ciphertext to bytes and decrypt it with the key
#      59 target_ciphertext = bytes.fromhex(target_ciphertext_hex)
#
# Cell In[15], line 24, in get_key(ciphertexts)
#      22         # Assuming that a space (0x20) was XORed with a letter
#      23         if 65 <= byte_xor ^ 0x20 <= 90 or 97 <= byte_xor ^ 0x20 <= 122:
# ---> 24             if key[i//2] is None:
#      25                 key[i//2] = byte_xor ^ 0x20
#      26 return key
#
# IndexError: list index out of range

# %%
from itertools import combinations

def hex_xor(hex1, hex2):
    """XOR two hex strings."""
    # Find the shorter length
    length = min(len(hex1), len(hex2))
    # Truncate the longer string and XOR bit by bit
    xor = int(hex1[:length], 16) ^ int(hex2[:length], 16)
    # Return as hex with left zero padding
    return f"{xor:0{length}x}"

def get_key(ciphertexts):
    """Given a list of ciphertexts, attempt to derive the key."""
    # Determine the minimum ciphertext length
    min_length = min(map(len, ciphertexts))
    key = [None] * (min_length // 2)  # initialize the shortest length of the ciphertexts
    # Try to find the key by XORing all combinations of ciphertexts
    for idx_a, idx_b in combinations(range(len(ciphertexts)), 2):
        ct_a, ct_b = ciphertexts[idx_a], ciphertexts[idx_b]
        # Only consider the overlapping part of both ciphertexts
        xor_result = hex_xor(ct_a.hex(), ct_b.hex())
        for i in range(0, min(len(xor_result), min_length), 2):
            byte_xor = int(xor_result[i:i+2], 16)
            # Assuming that a space (0x20) was XORed with a letter
            if 65 <= byte_xor ^ 0x20 <= 90 or 97 <= byte_xor ^ 0x20 <= 122:
                byte_pos = i // 2
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"



# Convert all hex ciphertexts to byte arrays
ciphertexts = [bytes.fromhex(ct) for ct in ciphertexts_hex]

# Derive the key using the ciphertexts
key = get_key(ciphertexts)

# Convert the target ciphertext to bytes and decrypt it with the key
target_ciphertext = bytes.fromhex(target_ciphertext_hex)
decrypted_target = decrypt_with_key(target_ciphertext, key)

# Print the decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 58
#      55 ciphertexts = [bytes.fromhex(ct) for ct in ciphertexts_hex]
#      57 # Derive the key using the ciphertexts
# ---> 58 key = get_key(ciphertexts)
#      60 # Convert the target ciphertext to bytes and decrypt it with the key
#      61 target_ciphertext = bytes.fromhex(target_ciphertext_hex)
#
# Cell In[16], line 27, in get_key(ciphertexts)
#      25         if 65 <= byte_xor ^ 0x20 <= 90 or 97 <= byte_xor ^ 0x20 <= 122:
#      26             byte_pos = i // 2
# ---> 27             if key[byte_pos] is None:
#      28                 key[byte_pos] = byte_xor ^ 0x20
#      29 return key
#
# IndexError: list index out of range

# %%
from itertools import combinations

def hex_xor(hex1, hex2):
    """XOR two hex strings of equal length."""
    return ''.join(f"{int(a, 16) ^ int(b, 16):02x}" for a, b in zip(hex1, hex2))

def get_likely_spaces(xor_result):
    """Find likely spaces in the XOR result by looking for the hex value of a space XORed with characters."""
    spaces = []
    for i in range(0, len(xor_result), 2):
        xor_val = int(xor_result[i:i+2], 16)
        # Check if the XORed result is in the range of printable characters
        if 0x20 <= xor_val <= 0x7E:
            spaces.append(i // 2)
    return spaces

def decrypt_with_key(ciphertext, key):
    """Attempt to decrypt a message using the derived key."""
    decrypted = []
    for i in range(len(ciphertext)):
        if i < len(key) and key[i] is not None:
            decrypted.append(chr(ciphertext[i] ^ key[i]))
        else:
            decrypted.append('*')
    return ''.join(decrypted)

# Convert hex-encoded ciphertexts to byte arrays

# Hex-encoded ciphertexts
c1="71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4ba85d8e1fa14f11d1c3b568ff6cff5c09c5d67ef5c9c71b7eeb3d45a5154ab17b83e071ce9d8988adb4afedf46a840"
c2="71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa0f012f95819681ae7f29fe4839b5175ef5e8760bef0b9d44b504eba12b22f5404f89dd085d550a48865a14f9b15a94dabe609ca2df2cccf210cefdb1af5389719795e1f0179cb77c5c456954d88f3"
c3="72fe069c51c81a20775928c7879d4fd2a93c3acff3f69fe5fe2e9493a303d9ea98c4e5b60ae40a146058e7c787fbd09a1474e25dc865b5e6af865d4a40a61bfd384e06e0cfc1ccd356ff8853ac438905fa5fe3fd41cb3bbc8ac9"
c4="67e543885b9a5b2267177084cf8453ccb8633ad7fdb39de5b13f8a93a304d6bf8bc4f4ef5def110b6f56a3e186e2c68c1470ef5c9c2ffbd6a291571e40ba1afd3b4b1fe0c4cbccc15df5dc07b043da01fa6ae4fd158f37b3c0cd"
c5="71fe029a148c1236320d7192878a59cfbc3a6ec5e7f68befb13196d6ea1ec4ea81d9e3fe50ea0f196d02a2f7cfe2c29c5577e35d8630baf6ea80465b01aa1abc394f57a1f4ccccda59ff8846e44b8805bb5cabe608c231f2dec8364ae7d90ab4358c5c3a421b06"
c6="6ef914ce5989152b321a769ad79c42c7be6f6ad2fab19de1fc339d84f04ad3a589dfa0ff09ab0c196f13e7e780b4c097556ded57c871fbeea393464a01aa0ab1381848cfd2d6898918efc046b00b8940bb08e3f313cb23b3dfd8645cfcd80ff82489"
c7="71fe1ace4389087266117cd7c4865bd2b93b7fd2b5a58ce9f4308c9ff01e97ab82cbf2ef5dfc101d6a56b3fb8ab4d08b4167ef5c9c30b8f0ab97455b45e81efd364605e49ddb83df48eedc42b60c900fb14db4b229ca74b6c4d96442e1c34df8288f5c3a450a527ecc7c82865b8e"
c8="71fe029a148c1437615978d7c58854dbec2c75cde5a39be5e37e9b97ef0697a285dfa0f01cff101d764983f29bf5"
c9="71fe1ace50875b31730d6ad7cb8640c7ec3c73d4e1bf81e7b13796d6e518d8a4988ceff05dff101d2415a8fe9fe1d79a4623eb5e8430bfe3b3d442514faf40fd18420be0c8cb89924cf3cd5ee448950efd5cabe500c120f2d9d26440ebc34de029811977430b01748276d79012955cc6a65aebb9054becda5c9278"
c10="71fe029a1483123c76597691878459cca9363ac4faf68ceffc2e8d82e61897b98fc5e5f809e20b0c7756b2e08aab83bc5560e257"
target_cipher_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]
ciphertexts_bytes = [
    [bytes.fromhex(ct) for ct in ciphertexts_hex]
]

# Initialize key with None
key = [None] * min(len(ct) for ct in ciphertexts_bytes)

# XOR ciphertexts and find likely space positions
for a, b in combinations(ciphertexts_bytes, 2):
    xor_result = hex_xor(a.hex(), b.hex())
    spaces = get_likely_spaces(xor_result)
    for space in spaces:
        if key[space] is None:
            key[space] = a[space] ^ 0x20  # Assuming that space is a space (' ')

# Target ciphertext for decryption
target_cipher_bytes = bytes.fromhex(
    "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"
)

# Decrypt the target ciphertext with the partial key
decrypted_target = decrypt_with_key(target_cipher_bytes, key)

# Print the partially decrypted target message
print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# Decrypted Target Message (partial): ***********************************************************

# %%
from itertools import combinations

def hex_xor(hex1, hex2):
    """XOR two hex strings."""
    max_len = max(len(hex1), len(hex2))
    hex1, hex2 = hex1.zfill(max_len), hex2.zfill(max_len)
    xor = int(hex1, 16) ^ int(hex2, 16)
    return f"{xor:0{max_len}x}"

def decrypt_with_key(ciphertext, key):
    """Attempt to decrypt a message using the derived key."""
    decrypted = []
    for i, byte in enumerate(ciphertext):
        if i < len(key) and key[i] is not None:
ciphertexts = [c1, c2, c3, c4, c5, c6, c7, c8, c9, c10]

# Manual key refinement based on XOR results and insights
key = [None] * 1024  # Initial key size, adjust based on your ciphertexts' lengths

# Example manual key adjustments based on observed patterns:
# key[position] = guessed_byte_value

# Add the target ciphertext here (hex encoded)
target_ciphertext_hex = "71fe0680149d083b7c1e3996879a42d0a92e7780f6bf9fe8f42cd898e61cd2b8ccd9f3f35dff101d241da2eacff9cc8d5123fe5a897efbeda4974b"

# Convert hex-encoded target ciphertext to byte array
target_ciphertext = bytes.fromhex(target_ciphertext_hex)

# Print XOR results for manual inspection
print_xor_results(ciphertexts)

# Reminder message
print("\nInspect the XOR results above and adjust the 'key' variable based on your insights.\n")

# Use the refined key to attempt decryption of the target message
# You'll need to uncomment and adjust the following lines based on your manual key adjustments
# decrypted_target = decrypt_with_key(target_ciphertext, key)
# print(f"Decrypted Target Message (partial): {decrypted_target}")
# Out:
# Ciphertext 0 XOR Ciphertext 1: 71fe1ace559a1e7266117cd7ce8745d7be2e74c3f0f68eeef57e8884e607debf81dfa081ece3965ae11295948e985452dd346ddb9c5a71030952a8a8712ec4592a90be7d45317fc1a1b9945ef7c06dda5c8d37bb6e25716ebd78cfbf3b814ba19380a1475903e8a153fd1e8ea84a0b20b3
# Ciphertext 0 XOR Ciphertext 2: 72fe069c51c81a20775928c7f663551ceab532bd95e7e33237a2d5112618e3256b746355f2db9ec28b5d237d022331600085ff41f3333a1060739dd61dc1f4a1a43fb10e7c15968202549feb924495ec22c769260b35e4fa2289
# Ciphertext 0 XOR Ciphertext 3: 67e543885b9a5b2267177084be7a4902fbea32a59ba2e13278b3cb11261fec707874720ca5d085dd8453675b033a27760081f240a77974206d6497821dddf5a1a73aa80e771f9690095ecbbf8e44c6e822f26e265f71e8f5688d
# Ciphertext 0 XOR Ciphertext 4: 71fe029a148c1236320d7192878a59cfbc3a6ec5e7f68befb14068cc245d4de2f3bff28287238358ef87b9cd0011721ab68fdcc950dbbf3250059ebafbbeeba12574012e0203391ac5a2efa9b8d7f9b255ef7fbc59969ae566f631560e01923eeec6a2e504b346
# Ciphertext 0 XOR Ciphertext 5: 6ef914ce5989152b321a769ad79c42c7be6f6ad28b4f872fbfba95f6965baf724053e17d8cb036d69ca36104788b5441be6829ed4da91a14b7625b563afc8547f7ed88538fb166d5849e77a803dfd311efa3f44b2dcc3f5a0740ee87b626d0be8cc9
# Ciphertext 0 XOR Ciphertext 6: 71fe1ace4389087266117cd7c4865bd2b93b7fd2b5a58ce9f4308c9ff01e97abf335e8211e75186f0c47cf2c43389109c47cd5936f803e1353a8d18daeedda47b39ee41e892a9ec373b853b479f95093ec2a5beeb5bbc358770d3e13b5685a40168840d39d92d8a586825dc0f3ce
# Ciphertext 0 XOR Ciphertext 7: 71fe1ace4389087266117cd7c98c4182851b3acff3b086e3f83f94d6eb05c4baf426e360007d092b5a0ff7210a7d9447b14b9a9179d22c0b50aac1c6bbad801abbd8bc19c4679ac63cb75cb433b5
